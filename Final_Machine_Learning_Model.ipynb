# %%
#import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('/content/USA_Housing.csv')

# %% [markdown]
# # **Data Preparation**

# %%
#check Dataset
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# checking null data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
#Checking Data types
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
df.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# 4992      87499.125743             6.403473                   4.836091
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4990                          6.39     14802.088438  4.795006e+05
# ...

# %%
#drop column
df = df.drop(['Address'],axis=1)

# %%
df.shape
# Out:
# (5000, 6)

# %%
#check data Null
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
#check data duplicated
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990             52723                    5                          8
# 4991             74102                    5                          7
# 4992             87499                    6                          4
# 4993             69639                    5                          7
# 4994             73060                    5                          6
# 4995             60567                    7                          6
# 4996             78491                    6                          6
# 4997             63390                    7                          4
# 4998             68001                    5                          7
# 4999             65510                    5                          6
#
#       Avg. Area Number of Bedrooms  Area Population    Price
# 4990                             6            14802   479500
# 4991                             3            24041  1263720
# ...

# %%
#convert data type float to integer
df['Price'] = df['Price'].astype('int')
df['Avg. Area Income'] = df['Avg. Area Income'].astype('int')
df['Avg. Area House Age'] = df['Avg. Area House Age'].astype('int')
df['Avg. Area Number of Rooms'] = df['Avg. Area Number of Rooms'].astype('int')
df['Avg. Area Number of Bedrooms'] = df['Avg. Area Number of Bedrooms'].astype('int')
df['Area Population'] = df['Area Population'].astype('int')

# %% [markdown]
# Tujuan mengubah data type float menjadi integer adalah untuk mempercepat pemrosesan data serta mencegah terjadinya overflow yang disebabkanoleh  float. Tidak hanya itu, hal ini  juga  agar  nilai  dari  attribute  tersebut  dapat  dihitung  serta  dapat  meningkatkan persentase keberhasilan dari model yang didigunaka

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68582.614400             5.481000                   6.492200
# std        10657.985126             1.034144                   1.048503
# min        17796.000000             2.000000                   3.000000
# 25%        61480.250000             5.000000                   6.000000
# 50%        68804.000000             5.000000                   7.000000
# 75%        75783.000000             6.000000                   7.000000
# max       107701.000000             9.000000                  10.000000
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000       5000.00000  5.000000e+03
# mean                       3.732400      36163.01500  1.232072e+06
# std                        1.225843       9925.64664  3.531176e+05
# ...

# %% [markdown]
# # **EDA**

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['Avg. Area Income'])

f.add_subplot(1,2,2)
sns.boxplot(x = df['Avg. Area Income'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['Avg. Area House Age'])

f.add_subplot(1,2,2)
sns.boxplot(x = df['Avg. Area House Age'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['Avg. Area Number of Rooms'])

f.add_subplot(1,2,2)
sns.boxplot(x = df['Avg. Area Number of Rooms'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['Avg. Area Number of Bedrooms'])

f.add_subplot(1,2,2)
sns.boxplot(x = df['Avg. Area Number of Bedrooms'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['Area Population'])

f.add_subplot(1,2,2)
sns.boxplot(x = df['Area Population'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Avg. Area Number of Bedrooms', 'Area Population'], y_vars=['Price']
             , size=5, aspect=0.75)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,size=5).map(sns.distplot,"Price").add_legend()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.hist(figsize = (10, 10))
plt.show()

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
corr = df.corr(method='pearson')
corr['Price'].sort_values(ascending = False)
# Out:
# Price                           1.000000
# Avg. Area Income                0.639734
# Avg. Area House Age             0.439171
# Area Population                 0.408556
# Avg. Area Number of Rooms       0.325114
# Avg. Area Number of Bedrooms    0.172429
# Name: Price, dtype: float64

# %%
df.corr().style.background_gradient().set_precision(2)
# Out:
# <ipython-input-26-62540e5ff327>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient().set_precision(2)
# <style type="text/css">
# #T_81632_row0_col0, #T_81632_row1_col1, #T_81632_row2_col2, #T_81632_row3_col3, #T_81632_row4_col4, #T_81632_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_81632_row0_col1, #T_81632_row1_col0, #T_81632_row2_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_81632_row0_col2, #T_81632_row1_col2, #T_81632_row3_col4, #T_81632_row3_col5, #T_81632_row4_col0, #T_81632_row4_col1, #T_81632_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_81632_row0_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_81632_row0_col4, #T_81632_row1_col4, #T_81632_row2_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_81632_row0_col5 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_81632_row1_col3 {
# ...

# %% [markdown]
# # **Modelling**

# %%
#spliting
from sklearn.model_selection import train_test_split
x = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
               'Avg. Area Number of Bedrooms', 'Area Population']]
y = df['Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
#Apply the model Linear Regression
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#predicting Test Data
y_pred= lin_reg.predict(x_test)
pd.DataFrame({'y_Test': y_test,'y_Pred':y_pred})[:5]
# Out:
#        y_Test        y_Pred
# 1501  1339096  1.377052e+06
# 2586  1251794  1.117917e+06
# 2653  1340094  1.181436e+06
# 1055  1431507  1.204411e+06
# 705   1042373  1.111848e+06

# %%
#Train the Model
pd.DataFrame(lin_reg.coef_ , x.columns ,columns=['coefcient'])
# Out:
#                                   coefcient
# Avg. Area Income                  21.553270
# Avg. Area House Age           151356.924948
# Avg. Area Number of Rooms     110818.304815
# Avg. Area Number of Bedrooms    1577.707540
# Area Population                   15.137650

# %%
print(lin_reg.intercept_)
# Out:
# -2349841.110448323

# %%
x_train.shape, x_test.shape
# Out:
# ((3500, 5), (1500, 5))

# %%
#model accuracy
lin_reg.score(x_test, y_test)
# Out:
# 0.887425207198619

# %%
y_pred = lin_reg.predict(x_test)
out=pd.DataFrame({'Price_actual':y_test,'Price_pred':y_pred})
result=df.merge(out,left_index=True,right_index=True)

result.sample(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 356              62431                    6                          8
# 2223             59114                    4                          5
# 3403             66616                    6                          5
# 1360             56825                    6                          7
# 199              59362                    7                          8
# 4961             45610                    6                          7
# 2168             44426                    6                          8
# 679              84364                    4                          7
# 3410             46885                    5                          6
# 4743             83846                    6                          6
#
#       Avg. Area Number of Bedrooms  Area Population    Price  Price_actual  \
# 356                              4            44115  1523915       1523915
# ...
